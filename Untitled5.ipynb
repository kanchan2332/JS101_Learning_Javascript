# %% [markdown]
# <a href="https://colab.research.google.com/github/kanchan2332/JS101_Learning_Javascript/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
_list =["a","b","c","a","a","d","%","^","*","d","c","c","*","%"]
_dict={}
count=0
for item in _list:
  if item in _dict:

    _dict[item]+=1
  else:
    _dict[item]=1
print(_dict)
# Out:
# {'a': 3, 'b': 1, 'c': 3, 'd': 2, '%': 2, '^': 1, '*': 2}

# %%
i=input()
n4=len(i)
print(n4//2)
# Out:
# radar
# 2

# %%
# cotez series 6->3->10->5->16->8->4->2->1
num =int(input("ener a number"))

while num!=1:
  print(num,end="->")
  if num%2==0:
    num//=2
  else:
    num=num*3+1
# Out:
# ener a number6
# 6->3->10->5->16->8->4->2->

# %%
n=int(input())
for i in range(1,n+1):
  j=str(i)
  print(f"{j*i}")
# Out:
# 5
# 1
# 22
# 333
# 4444
# 55555

# %%
_n1="2"
print(_n1*3)
# Out:
# 222

# %%
_list3=[23,45,67,89]
list4=[]
for i in _list3:

  for j in list(i):
    list4.append(j)
    print(list4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2752474528.py in <cell line: 0>()
#       2 list4=[]
#       3 for i in _list3:
# ----> 4   for j in list(i):
#       5     list4.append(j)
#       6     print(list4)
#
# TypeError: 'int' object is not iterable

# %%
list1=["a","b","c"]
list2=[23,53,89]
_dict={}
for i,j in zip(list1,list2):
  _dict[i]=j
print(_dict)
# Out:
# {'a': 23, 'b': 53, 'c': 89}

# %%
_list1=eval(input("enter a list"))#eval function exectes within questes lists item  take as inut
remove=input("enter item which you want to remove")
if remove in _list1:
  _list1.remove(remove)
print(_list1)
# Out:
# enter a list["car","bike"]
# enter item which you want to removebike
# ['car']
